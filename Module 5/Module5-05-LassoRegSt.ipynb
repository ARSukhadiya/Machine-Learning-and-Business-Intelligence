# %% [markdown]
# # Lasso

# %%
line = np.linspace(-2, 2, 1001)
plt.plot(line, line ** 2, label="L2")
plt.plot(line, np.abs(line), label="L1")
plt.plot(line, line!=0, label="L0")
plt.legend()
plt.savefig("Fig/l2_l1_l0.png")

# %%
line = np.linspace(-1, 1, 1001)

alpha_l1 = 10
alpha_l2 = 10

f_x = (2 * line - 1) ** 2
f_x_l2 =  f_x + alpha_l2 * line ** 2
f_x_l1 =  f_x + alpha_l1 * np.abs(line)

print(line[np.argmin(f_x)])
print(line[np.argmin(f_x_l2)])
print(line[np.argmin(f_x_l1)])

plt.plot(line, f_x, label="f(x)")
plt.plot(line, f_x_l2, label="f(x) + L2")
plt.plot(line, f_x_l1, label="f(x) + L1")
plt.legend()
plt.savefig("Fig/l1_kink.png")
# Out:
# 0.5
# 0.14200000000000013
# 0.0

# %%
xline = np.linspace(-2., 2, 1001)
yline = np.linspace(-2, 2, 1001)
xx, yy = np.meshgrid(xline, yline)

# %%
len(yy)
# Out:
# 1001

# %%
l2 = xx ** 2 + yy ** 2
l1 = np.abs(xx) + np.abs(yy)

# %%
l2_contour = plt.contour(xx, yy, l2, levels=[1], colors='k')
ax = plt.gca()
ax.set_aspect("equal")
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')

ax.set_xticks(np.arange(-2, 2, .5))
ax.set_yticks([-1,-0.5, 0.5, 1]);

# %%
xline = np.linspace(-1, 1, 1001)
yline = np.linspace(-1, 1, 1001)
xx, yy = np.meshgrid(xline, yline)

l2 = xx ** 2 + yy ** 2
l1 = np.abs(xx) + np.abs(yy)

plt.figure(figsize=(5, 5))
l2_contour = plt.contour(xx, yy, l2, levels=1, colors='k')
l1_contour = plt.contour(xx, yy, l1, levels=1, colors='k')
ax = plt.gca()
ax.set_aspect("equal")
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')
plt.clabel(l2_contour, inline=1, fontsize=10, fmt={1.0: 'L2'}, manual=[(-1, -1)])
plt.clabel(l1_contour, inline=1, fontsize=10, fmt={1.0: 'L1'}, manual=[(-1, -1)])

ax.set_xticks(np.arange(-2, 2, .5))
ax.set_yticks(np.arange(-2, 2, .5));
plt.savefig("Fig/l1l2ball.png")

# %%
xline = np.linspace(-2., 2, 1001)
yline = np.linspace(-2, 2, 1001)
xx, yy = np.meshgrid(xline, yline)


l2 = xx ** 2 + yy ** 2
l1 = np.abs(xx) + np.abs(yy)

quadratic = np.sqrt(2 * (xx - 2.) ** 2 + (yy - 1.7) ** 2 + xx * yy)

plt.figure(figsize=(10, 10))
l2_contour = plt.contour(xx, yy, l2, levels=[1], colors='k')
l1_contour = plt.contour(xx, yy, l1, levels=[1], colors='k')
quadratic_contour = plt.contour(xx, yy, quadratic, levels=[1.6, 1.7, 1.8, 1.9, 2, 2.1, 2.2, 2.3])


ax = plt.gca()
ax.set_aspect("equal")
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')
plt.clabel(l2_contour, inline=1, fontsize=10, fmt={1.0: 'L2'}, manual=[(-1, -1)])
plt.clabel(l1_contour, inline=1, fontsize=10, fmt={1.0: 'L1'}, manual=[(-1, -1)])
#plt.clabel(quadratic_contour, inline=1, fontsize=10)

ax.set_xticks(np.arange(-2, 2, .5))
ax.set_yticks(np.arange(-2, 2, .5));
#ax.set_xticks(np.arange(-2, 2, .5))
#ax.set_yticks([.5, 1, 2])
plt.savefig("Fig/l1l2ball_intersect.png")

# %% [markdown]
# ### Lasso Implementation

# %% [markdown]
# - Transform the Boston House dataset using polynomial transformation and split the dataset into test and train datasets
# - Run cross validation with Lasso Regression
# - Plot the coefficients of the model

# %% [markdown]
# - Start a grid search for `alpha` value
# - Plot the model performance versus the different `alpha` values

# %% [markdown]
# - Print the best parameter score
# - Print the best model score

# %% [markdown]
# - Plot the model coefficients
